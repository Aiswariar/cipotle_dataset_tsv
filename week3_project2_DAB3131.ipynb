# %% [markdown]
# <a href="https://colab.research.google.com/github/Aiswariar/cipotle_dataset_tsv/blob/main/week3_project2_DAB3131.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/chipotle.tsv',sep="\t")

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.shape
# Out:
# (4622, 5)

# %%
df[df.duplicated()]
# Out:
#       order_id  quantity                            item_name  \
# 238        103         1                        Steak Burrito
# 248        108         1                          Canned Soda
# 297        129         1                        Steak Burrito
# 381        165         1                    Canned Soft Drink
# 484        205         1                         Chicken Bowl
# 567        233         1                    Canned Soft Drink
# 617        254         1                                Chips
# 684        282         1                    Canned Soft Drink
# 773        319         1                         Chicken Bowl
# 908        376         1                        Steak Burrito
# 924        381         1                   Chicken Soft Tacos
# 1003       412         1                        Bottled Water
# 1117       462         1                      Chicken Burrito
# 1203       491         1                      Chicken Burrito
# ...

# %%
df2 = df.drop_duplicates()

# %%
df2.shape
# Out:
# (4563, 5)

# %%
df['choice_description'].value_counts()
# Out:
# choice_description
# [Diet Coke]                                                                                                                                      134
# [Coke]                                                                                                                                           123
# [Sprite]                                                                                                                                          77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                            42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                 40
#                                                                                                                                                 ...
# ...

# %%
df['choice_description'] = df['choice_description'].replace(np.nan,"Not Available")
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                      Not Available     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                      Not Available     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.isna().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64

# %%
df2.shape
# Out:
# (4563, 5)

# %%
df2['item_price']=df2['item_price'].apply(lambda x:x.replace("$",""))
print(df2['item_price'])
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4563, dtype: object
# <ipython-input-13-bf0eac1e2863>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['item_price']=df2['item_price'].apply(lambda x:x.replace("$",""))

# %%
df2['item_price']=df2['item_price'].astype(float)
df2.head()
# Out:
# <ipython-input-14-83fb16c6cc76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['item_price']=df2['item_price'].astype(float)
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# ...

# %% [markdown]
# 1.Quantity of each item?

# %%
d = df2.groupby('item_name').sum()
d = d.sort_values(['quantity'],ascending=False)
d.head(5)
# Out:
#                      order_id  quantity  \
# item_name
# Chicken Bowl           704980       752
# Chicken Burrito        490718       584
# Chips and Guacamole    443669       501
# Steak Burrito          327829       383
# Canned Soft Drink      296817       340
#
#                                                     choice_description  \
# item_name
# Chicken Bowl         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# Chicken Burrito      [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# Chips and Guacamole                                                  0
# Steak Burrito        [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# Canned Soft Drink    [Coke][Sprite][Coke][Coke][Lemonade][Sprite][D...
#
#                      item_price
# item_name
# Chicken Bowl            7259.75
# Chicken Burrito         5509.57
# Chips and Guacamole     2178.79
# Steak Burrito           3818.94
# Canned Soft Drink        425.00

# %% [markdown]
# 2.What was the most ordered item in the choice_description column?

# %%
df2['choice_description'].value_counts().head(1)
# Out:
# choice_description
# [Diet Coke]    133
# Name: count, dtype: int64

# %% [markdown]
# 3.How many items were ordered in total?

# %%
total_ordered_item= df.quantity.sum()
print(total_ordered_item)
# Out:
# 4972

# %%
df2['quantity'].sum()
# Out:
# 4913

# %% [markdown]
# 4.How much was the revenue for the period in the dataset?

# %%
df2.head()
revenue=df2['item_price'].sum()
print(revenue)
# Out:
# 34177.25

# %% [markdown]
# 5.How many orders were made in the period?

# %%
order_count=df['order_id'].value_counts().count()
print(order_count)
# Out:
# 1834

# %% [markdown]
# 6.What is the average revenue amount per order?

# %%
df2.loc[:,'revenue']= df2['quantity']*df2['item_price']
print(df2['revenue'])
total_revenue=df2['revenue'].sum()
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       33.96
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: revenue, Length: 4563, dtype: float64
# <ipython-input-21-d8085f9a70cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:,'revenue']= df2['quantity']*df2['item_price']

# %%
data = df2.groupby(by=['order_id']).sum()
print(data)
data['revenue'].mean()
# Out:
#           quantity                                          item_name  \
# order_id
# 1                4  Chips and Fresh Tomato SalsaIzzeNantucket Nect...
# 2                2                                       Chicken Bowl
# 3                2                          Chicken BowlSide of Chips
# 4                2                      Steak BurritoSteak Soft Tacos
# 5                2                   Steak BurritoChips and Guacamole
# ...            ...                                                ...
# 1830             2                        Steak BurritoVeggie Burrito
# 1831             3                    Carnitas BowlChipsBottled Water
# 1832             2              Chicken Soft TacosChips and Guacamole
# 1833             2                         Steak BurritoSteak Burrito
# 1834             3  Chicken Salad BowlChicken Salad BowlChicken Sa...
#
#                                          choice_description  item_price  \
# order_id
# ...

# %% [markdown]
# 7.How many different items are sold?

# %%
sold_items=df2['item_name'].value_counts().count()
print(sold_items)
# Out:
# 50

# %%
df2.shape
# Out:
# (4563, 6)
